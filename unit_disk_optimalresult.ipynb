# %%
import math
import torch
from torch.autograd import Variable
import torch.nn.functional as F
import matplotlib.pyplot as plt
import numpy as np

# %%
# exact solution u(x) for pde
def func_u(x):
    u=(1-(x[:,0]**2)-(x[:,1]**2))/4
    return u 

# f(x) = 1
def func_f(x):
    f = 1
    return (f)

def func_g(x):
    g = 0
    return (g)

# w_val
def func_w(x):
    lens = x.shape[0]
    w_bool = torch.gt(torch.zeros(lens), 1-(x[:,0]**2+x[:,1]**2))
    w_val = torch.where(w_bool, torch.zeros(lens), 1-(x[:,0]**2+x[:,1]**2))
    return (w_val)



# define generator and discriminator neural network
class generator(torch.nn.Module):
    def __init__(self):
        super(generator,self).__init__()
        self.hidden00=torch.nn.Linear(dim, u_hidden_size)
        torch.nn.init.kaiming_uniform_(self.hidden00.weight, a=0.1, mode='fan_in', nonlinearity='leaky_relu')
        #torch.nn.init.constant(self.hidden00.bias, -0.5)
        self.hidden0=torch.nn.Linear(u_hidden_size, u_hidden_size)
        torch.nn.init.kaiming_uniform_(self.hidden0.weight, a=0.1, mode='fan_in', nonlinearity='leaky_relu')
        self.hidden1=torch.nn.Linear(u_hidden_size, u_hidden_size)
        torch.nn.init.kaiming_uniform_(self.hidden1.weight, a=0.1, mode='fan_in', nonlinearity='leaky_relu')
        #self.hidden2=torch.nn.Linear(u_hidden_size, u_hidden_size)
        #torch.nn.init.kaiming_uniform_(self.hidden2.weight, a=0.1, mode='fan_in', nonlinearity='leaky_relu')
        #self.hidden3=torch.nn.Linear(u_hidden_size, u_hidden_size)
        #torch.nn.init.kaiming_uniform_(self.hidden3.weight, a=0.1, mode='fan_in', nonlinearity='leaky_relu')
        #self.hidden4=torch.nn.Linear(u_hidden_size, u_hidden_size)
        #torch.nn.init.kaiming_uniform_(self.hidden4.weight, a=0.1, mode='fan_in', nonlinearity='leaky_relu')
        #self.hidden5=torch.nn.Linear(u_hidden_size, u_hidden_size)
        #torch.nn.init.kaiming_uniform_(self.hidden5.weight, a=0.1, mode='fan_in', nonlinearity='leaky_relu')
        #self.hidden6=torch.nn.Linear(u_hidden_size, u_hidden_size)
        #torch.nn.init.kaiming_uniform_(self.hidden6.weight, a=0.1, mode='fan_in', nonlinearity='leaky_relu')
        self.predict=torch.nn.Linear(u_hidden_size, out_size)
        torch.nn.init.kaiming_uniform_(self.predict.weight, a=0.1, mode='fan_in', nonlinearity='leaky_relu')
        
    def forward(self, x):
        x=F.leaky_relu(self.hidden00(x))
        x=F.leaky_relu(self.hidden0(x))
        x=F.leaky_relu(self.hidden1(x))
        #x=F.leaky_relu(self.hidden2(x))
        #x=F.leaky_relu(self.hidden3(x))
        #x=F.leaky_relu(self.hidden4(x))
        #x=F.leaky_relu(self.hidden5(x))
        #x=F.leaky_relu(self.hidden6(x))
        x=self.predict(x)
        return(x)

    def backward(self, retain_graph=True):
        self.loss.backward(retain_graph=retain_graph)
        return(self.loss)

class discriminator(torch.nn.Module):
    def __init__(self):
        super(discriminator,self).__init__()
        self.hidden00_v=torch.nn.Linear(dim, v_hidden_size)
        torch.nn.init.kaiming_uniform_(self.hidden00_v.weight, a=0.1, mode='fan_in', nonlinearity='leaky_relu')
        self.hidden0_v=torch.nn.Linear(v_hidden_size, v_hidden_size)
        torch.nn.init.kaiming_uniform_(self.hidden0_v.weight, a=0.1, mode='fan_in', nonlinearity='leaky_relu')
        self.hidden1_v=torch.nn.Linear(v_hidden_size, v_hidden_size)
        torch.nn.init.kaiming_uniform_(self.hidden1_v.weight, a=0.1, mode='fan_in', nonlinearity='leaky_relu')
        #self.hidden2_v=torch.nn.Linear(v_hidden_size, v_hidden_size)
        #torch.nn.init.kaiming_uniform_(self.hidden2_v.weight, a=0.1, mode='fan_in', nonlinearity='leaky_relu')
        #self.hidden3_v=torch.nn.Linear(v_hidden_size, v_hidden_size)
        #torch.nn.init.kaiming_uniform_(self.hidden3_v.weight, a=0.1, mode='fan_in', nonlinearity='leaky_relu')
        #self.hidden4_v=torch.nn.Linear(v_hidden_size, v_hidden_size)
        #torch.nn.init.kaiming_uniform_(self.hidden4_v.weight, a=0.1, mode='fan_in', nonlinearity='leaky_relu')
        #self.hidden5_v=torch.nn.Linear(v_hidden_size, v_hidden_size)
        #torch.nn.init.kaiming_uniform_(self.hidden5_v.weight, a=0.1, mode='fan_in', nonlinearity='leaky_relu')
        #self.hidden6_v=torch.nn.Linear(v_hidden_size, v_hidden_size)
        #torch.nn.init.kaiming_uniform_(self.hidden6_v.weight, a=0.1, mode='fan_in', nonlinearity='leaky_relu')
        self.predict_v=torch.nn.Linear(v_hidden_size, out_size)
        torch.nn.init.kaiming_uniform_(self.predict_v.weight, a=0.1, mode='fan_in', nonlinearity='leaky_relu')
        
    def forward(self, x):
        x=F.leaky_relu(self.hidden00_v(x))
        x=F.leaky_relu(self.hidden0_v(x))
        x=F.leaky_relu(self.hidden1_v(x))
        #x=F.leaky_relu(self.hidden2_v(x))
        #x=F.leaky_relu(self.hidden3_v(x))
        #x=F.leaky_relu(self.hidden4_v(x))
        #x=F.leaky_relu(self.hidden5_v(x))
        #x=F.leaky_relu(self.hidden6_v(x))
        x=self.predict_v(x)
        return(x)

    def backward(self, retain_graph=True):
        self.loss.backward(retain_graph=retain_graph)
        return(self.loss)



# grad_u
def grad_u(y_output_u):
    optimizer_u_0.zero_grad()
    lens = x_domain.shape[0]
    y_output_u.backward(torch.ones([lens,1]), retain_graph=True)
    grad_u = x_domain_.grad
    return(grad_u)  

# grad_phi
def grad_phi(y_output_v):
    optimizer_v_0.zero_grad()
    lens = x_domain.shape[0]
    w = torch.reshape(func_w(x_domain), (lens, 1))
    phi = y_output_v.mul(w)
    y_output_v.backward(torch.ones([lens, 1]), retain_graph=True)
    grad_phi = x_domain_.grad
    return (grad_phi)



# loss function
def I(y_output_u, y_output_v):
    temp_grad_u=grad_u(y_output_u)
    t1 = torch.sum(torch.mm(torch.transpose(temp_grad_u,0,1),grad_phi(y_output_v)))
    t = torch.sum(func_f(x_domain)*y_output_v)
    I = t1-t
    return(I)

def L_int(y_output_u, y_output_v):
    numerator = torch.log(torch.abs(I(y_output_u, y_output_v))**2)
    denominator = torch.log(torch.sum((y_output_v)**2)) 
    ratio=numerator-denominator
    return(ratio)

def L_bd():
    result = torch.mean((net_u(x_boundary_)-func_g(x_boundary))**2)
    return(result)

def Loss_u(y_output_u, y_output_v):
    return(L_int(y_output_u, y_output_v)+alpha*L_bd())

def Loss_v(y_output_u,y_output_v):
    return(-L_int(y_output_u, y_output_v))

# %%
# initial parameters(modified***)
up= 1.0
low= -1
dim= 2
mesh_size= 100
domain_size= 100
bound_size= 500
#
v_layer= 6
v_hidden_size= 20
v_step= 1       
v_rate=0.0002   
u_layer= 6
u_hidden_size= 20
u_step= 1
u_rate=0.0002
out_size=1
alpha=100



# x value in domain and boundary
# x_boundary
x_boundary_list=[]  #x_boundry
x_bound_1 = torch.Tensor(bound_size,1).uniform_(low,up)
x_bound_2 = torch.sqrt(1-x_bound_1**2)
x_bound_3 = -torch.sqrt(1-x_bound_1**2)
x_bound_4 = torch.Tensor(bound_size,1).uniform_(low,up)
x_bound_5 = torch.sqrt(1-x_bound_4**2)
x_bound_6 = -torch.sqrt(1-x_bound_4**2)
#
x_boundary_list.append(torch.cat((x_bound_1,x_bound_2),1))
x_boundary_list.append(torch.cat((x_bound_1,x_bound_3),1))
x_boundary_list.append(torch.cat((x_bound_5,x_bound_4),1))
x_boundary_list.append(torch.cat((x_bound_6,x_bound_4),1))
x_boundary = torch.cat((x_boundary_list[0],x_boundary_list[1], x_boundary_list[2], x_boundary_list[3]),0)



# x value for domain
x_mesh2=torch.linspace(low,up,domain_size)
y_mesh2=torch.linspace(low,up,domain_size)
mesh3,mesh4=torch.meshgrid(x_mesh2,y_mesh2)
x2=torch.reshape(mesh3,(-1,1))
y2=torch.reshape(mesh4,(-1,1))
x_domain0=torch.cat((x2,y2),1)
#
lens_x_domain0 = x_domain0.shape[0]
mask = torch.lt(torch.square(x_domain0[:,0])+torch.square(x_domain0[:,1]), torch.ones(lens_x_domain0))
x_domain1=torch.masked_select(x_domain0[:,0],mask)
x_domain2=torch.masked_select(x_domain0[:,1],mask)
x_domain1_=torch.reshape(x_domain1,(-1,1))
x_domain2_=torch.reshape(x_domain2,(-1,1))
x_domain=torch.cat((x_domain1_,x_domain2_),1)


# x value for network input
x_mesh = torch.linspace(low,up,mesh_size)
y_mesh = torch.Tensor(mesh_size,mesh_size)
for i in range(mesh_size):
    neg=-torch.sqrt(1-x_mesh[i]**2)
    pos=torch.sqrt(1-x_mesh[i]**2)
    y_mesh[i,:]=torch.linspace(neg.data.float(),pos.data.float(),mesh_size)
mesh1,mesh2=torch.meshgrid(x_mesh,x_mesh)
x_mesh_ = torch.reshape(mesh1,(-1,1))
y_mesh_ = torch.reshape(y_mesh,(-1,1))
x_test = torch.cat((x_mesh_,y_mesh_),1)

# %%
# torch variables
x_test_ = Variable(x_test)
x_test_.requires_grad_(True)
x_domain_=Variable(x_domain)
x_domain_.requires_grad_(True)
x_boundary_ = Variable(x_boundary)
u_test = func_u(x_test)
u_test_ = Variable(u_test)


# neural network models
net_u= generator()
net_v=discriminator()

# optimizers for grad_u and grad_phi
optimizer_u_0 = torch.optim.SGD(net_u.parameters(), lr = 0)
optimizer_v_0 = torch.optim.SGD(net_v.parameters(), lr = 0)

#optimizers for WAN
optimizer_u = torch.optim.Adam(net_u.parameters(), lr = u_rate) 
optimizer_v = torch.optim.Adam(net_v.parameters(), lr = v_rate)
# learning rate decays when loss doesn't change in 10 iterations
#scheduler_u = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer_u, mode='max', factor=0.6, patience=150, verbose=False, threshold=1e-04, threshold_mode='rel', cooldown=0, min_lr=0, eps=1e-08)
#scheduler_v = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer_v, mode='min', factor=0.6, patience=150, verbose=False, threshold=1e-04, threshold_mode='rel', cooldown=0, min_lr=0, eps=1e-08)

scheduler_u=torch.optim.lr_scheduler.StepLR(optimizer_u, step_size=2500, gamma=0.7, last_epoch=-1)  #每一个iteration实际是20个epoch
scheduler_v=torch.optim.lr_scheduler.StepLR(optimizer_v, step_size=2500, gamma=0.7, last_epoch=-1)

# %%
# 1
iteration = 501
n1 = 10
n2 = 10

prediction_u = net_u(x_domain_)
prediction_v = net_v(x_domain_)

for t in range(iteration):
    
        
    for i in range(n1):
        loss_u = Loss_u(prediction_u, prediction_v)
        optimizer_u.zero_grad()
        loss_u.backward(retain_graph=True)
        optimizer_u.step()
        scheduler_u.step() #loss_u
        prediction_u = net_u(x_domain_)
        
    
    for j in range(n2):
        loss_v = Loss_v(prediction_u,prediction_v)
        optimizer_v.zero_grad()
        loss_v.backward(retain_graph=True)
        optimizer_v.step()
        scheduler_v.step() #loss_v
        prediction_v = net_v(x_domain_)
            

    if t%10==0:
        print(t, loss_u, loss_v)
        print('第%d个epoch的学习率：%f'%(t, optimizer_u.param_groups[0]['lr']))
        print('第%d个epoch的学习率：%f'%(t, optimizer_v.param_groups[0]['lr']))
# Out:
# 0 tensor(23.6980, grad_fn=<AddBackward0>) tensor(-22.7325, grad_fn=<NegBackward>)
# 第0个epoch的学习率：0.000200
# 第0个epoch的学习率：0.000200
# 10 tensor(34.2300, grad_fn=<AddBackward0>) tensor(-34.4084, grad_fn=<NegBackward>)
# 第10个epoch的学习率：0.000200
# 第10个epoch的学习率：0.000200
# 20 tensor(39.5836, grad_fn=<AddBackward0>) tensor(-39.9560, grad_fn=<NegBackward>)
# 第20个epoch的学习率：0.000200
# 第20个epoch的学习率：0.000200
# 30 tensor(43.0849, grad_fn=<AddBackward0>) tensor(-43.1917, grad_fn=<NegBackward>)
# 第30个epoch的学习率：0.000200
# 第30个epoch的学习率：0.000200
# 40 tensor(44.7165, grad_fn=<AddBackward0>) tensor(-44.7758, grad_fn=<NegBackward>)
# 第40个epoch的学习率：0.000200
# 第40个epoch的学习率：0.000200
# 50 tensor(45.7811, grad_fn=<AddBackward0>) tensor(-45.8485, grad_fn=<NegBackward>)
# 第50个epoch的学习率：0.000200
# 第50个epoch的学习率：0.000200
# 60 tensor(46.6088, grad_fn=<AddBackward0>) tensor(-46.6783, grad_fn=<NegBackward>)
# 第60个epoch的学习率：0.000200
# 第60个epoch的学习率：0.000200
# 70 tensor(47.3710, grad_fn=<AddBackward0>) tensor(-47.3323, grad_fn=<NegBackward>)
# 第70个epoch的学习率：0.000200
# 第70个epoch的学习率：0.000200
# 80 tensor(47.9891, grad_fn=<AddBackward0>) tensor(-47.9837, grad_fn=<NegBackward>)
# 第80个epoch的学习率：0.000200
# 第80个epoch的学习率：0.000200
# 90 tensor(48.4573, grad_fn=<AddBackward0>) tensor(-48.5366, grad_fn=<NegBackward>)
# 第90个epoch的学习率：0.000200
# 第90个epoch的学习率：0.000200
# 100 tensor(48.9756, grad_fn=<AddBackward0>) tensor(-48.9396, grad_fn=<NegBackward>)
# 第100个epoch的学习率：0.000200
# 第100个epoch的学习率：0.000200
# 110 tensor(49.3705, grad_fn=<AddBackward0>) tensor(-49.3885, grad_fn=<NegBackward>)
# 第110个epoch的学习率：0.000200
# 第110个epoch的学习率：0.000200
# 120 tensor(49.7439, grad_fn=<AddBackward0>) tensor(-49.7606, grad_fn=<NegBackward>)
# 第120个epoch的学习率：0.000200
# 第120个epoch的学习率：0.000200
# 130 tensor(50.0903, grad_fn=<AddBackward0>) tensor(-50.1042, grad_fn=<NegBackward>)
# 第130个epoch的学习率：0.000200
# 第130个epoch的学习率：0.000200
# 140 tensor(50.4142, grad_fn=<AddBackward0>) tensor(-50.4292, grad_fn=<NegBackward>)
# 第140个epoch的学习率：0.000200
# 第140个epoch的学习率：0.000200
# 150 tensor(50.7288, grad_fn=<AddBackward0>) tensor(-50.7427, grad_fn=<NegBackward>)
# 第150个epoch的学习率：0.000200
# 第150个epoch的学习率：0.000200
# 160 tensor(51.0177, grad_fn=<AddBackward0>) tensor(-51.0309, grad_fn=<NegBackward>)
# 第160个epoch的学习率：0.000200
# 第160个epoch的学习率：0.000200
# 170 tensor(51.2879, grad_fn=<AddBackward0>) tensor(-51.3010, grad_fn=<NegBackward>)
# 第170个epoch的学习率：0.000200
# 第170个epoch的学习率：0.000200
# 180 tensor(51.5429, grad_fn=<AddBackward0>) tensor(-51.5557, grad_fn=<NegBackward>)
# 第180个epoch的学习率：0.000200
# 第180个epoch的学习率：0.000200
# 190 tensor(51.7840, grad_fn=<AddBackward0>) tensor(-51.7959, grad_fn=<NegBackward>)
# 第190个epoch的学习率：0.000200
# 第190个epoch的学习率：0.000200
# 200 tensor(52.0153, grad_fn=<AddBackward0>) tensor(-52.0265, grad_fn=<NegBackward>)
# 第200个epoch的学习率：0.000200
# 第200个epoch的学习率：0.000200
# 210 tensor(52.2387, grad_fn=<AddBackward0>) tensor(-52.2495, grad_fn=<NegBackward>)
# 第210个epoch的学习率：0.000200
# 第210个epoch的学习率：0.000200
# 220 tensor(52.4504, grad_fn=<AddBackward0>) tensor(-52.4610, grad_fn=<NegBackward>)
# 第220个epoch的学习率：0.000200
# 第220个epoch的学习率：0.000200
# 230 tensor(52.6508, grad_fn=<AddBackward0>) tensor(-52.6608, grad_fn=<NegBackward>)
# 第230个epoch的学习率：0.000200
# 第230个epoch的学习率：0.000200
# 240 tensor(52.8436, grad_fn=<AddBackward0>) tensor(-52.8533, grad_fn=<NegBackward>)
# 第240个epoch的学习率：0.000200
# 第240个epoch的学习率：0.000200
# 250 tensor(53.0311, grad_fn=<AddBackward0>) tensor(-53.0697, grad_fn=<NegBackward>)
# 第250个epoch的学习率：0.000140
# 第250个epoch的学习率：0.000140
# 260 tensor(53.2435, grad_fn=<AddBackward0>) tensor(-53.2522, grad_fn=<NegBackward>)
# 第260个epoch的学习率：0.000140
# 第260个epoch的学习率：0.000140
# 270 tensor(53.4124, grad_fn=<AddBackward0>) tensor(-53.4210, grad_fn=<NegBackward>)
# 第270个epoch的学习率：0.000140
# 第270个epoch的学习率：0.000140
# 280 tensor(53.5781, grad_fn=<AddBackward0>) tensor(-53.5864, grad_fn=<NegBackward>)
# 第280个epoch的学习率：0.000140
# 第280个epoch的学习率：0.000140
# 290 tensor(53.7395, grad_fn=<AddBackward0>) tensor(-53.7476, grad_fn=<NegBackward>)
# 第290个epoch的学习率：0.000140
# 第290个epoch的学习率：0.000140
# 300 tensor(53.8744, grad_fn=<AddBackward0>) tensor(-53.8843, grad_fn=<NegBackward>)
# 第300个epoch的学习率：0.000140
# 第300个epoch的学习率：0.000140
# 310 tensor(54.0274, grad_fn=<AddBackward0>) tensor(-54.0350, grad_fn=<NegBackward>)
# 第310个epoch的学习率：0.000140
# 第310个epoch的学习率：0.000140
# 320 tensor(54.1737, grad_fn=<AddBackward0>) tensor(-54.1808, grad_fn=<NegBackward>)
# 第320个epoch的学习率：0.000140
# 第320个epoch的学习率：0.000140
# 330 tensor(54.3150, grad_fn=<AddBackward0>) tensor(-54.3220, grad_fn=<NegBackward>)
# 第330个epoch的学习率：0.000140
# 第330个epoch的学习率：0.000140
# 340 tensor(54.4512, grad_fn=<AddBackward0>) tensor(-54.4580, grad_fn=<NegBackward>)
# 第340个epoch的学习率：0.000140
# 第340个epoch的学习率：0.000140
# 350 tensor(54.5833, grad_fn=<AddBackward0>) tensor(-54.5898, grad_fn=<NegBackward>)
# 第350个epoch的学习率：0.000140
# 第350个epoch的学习率：0.000140
# 360 tensor(54.7117, grad_fn=<AddBackward0>) tensor(-54.7181, grad_fn=<NegBackward>)
# 第360个epoch的学习率：0.000140
# 第360个epoch的学习率：0.000140
# 370 tensor(54.8356, grad_fn=<AddBackward0>) tensor(-54.8418, grad_fn=<NegBackward>)
# 第370个epoch的学习率：0.000140
# 第370个epoch的学习率：0.000140
# 380 tensor(54.9554, grad_fn=<AddBackward0>) tensor(-54.9616, grad_fn=<NegBackward>)
# 第380个epoch的学习率：0.000140
# 第380个epoch的学习率：0.000140
# 390 tensor(55.0710, grad_fn=<AddBackward0>) tensor(-55.0767, grad_fn=<NegBackward>)
# 第390个epoch的学习率：0.000140
# 第390个epoch的学习率：0.000140
# 400 tensor(55.1838, grad_fn=<AddBackward0>) tensor(-55.1890, grad_fn=<NegBackward>)
# 第400个epoch的学习率：0.000140
# 第400个epoch的学习率：0.000140
# 410 tensor(55.2938, grad_fn=<AddBackward0>) tensor(-55.2994, grad_fn=<NegBackward>)
# 第410个epoch的学习率：0.000140
# 第410个epoch的学习率：0.000140
# 420 tensor(55.4007, grad_fn=<AddBackward0>) tensor(-55.4062, grad_fn=<NegBackward>)
# 第420个epoch的学习率：0.000140
# 第420个epoch的学习率：0.000140
# 430 tensor(55.5051, grad_fn=<AddBackward0>) tensor(-55.5109, grad_fn=<NegBackward>)
# 第430个epoch的学习率：0.000140
# 第430个epoch的学习率：0.000140
# 440 tensor(55.6077, grad_fn=<AddBackward0>) tensor(-55.6131, grad_fn=<NegBackward>)
# 第440个epoch的学习率：0.000140
# 第440个epoch的学习率：0.000140
# 450 tensor(55.7078, grad_fn=<AddBackward0>) tensor(-55.7128, grad_fn=<NegBackward>)
# 第450个epoch的学习率：0.000140
# 第450个epoch的学习率：0.000140
# 460 tensor(55.8062, grad_fn=<AddBackward0>) tensor(-55.8105, grad_fn=<NegBackward>)
# 第460个epoch的学习率：0.000140
# 第460个epoch的学习率：0.000140
# 470 tensor(55.9013, grad_fn=<AddBackward0>) tensor(-55.9066, grad_fn=<NegBackward>)
# 第470个epoch的学习率：0.000140
# 第470个epoch的学习率：0.000140
# 480 tensor(55.9943, grad_fn=<AddBackward0>) tensor(-55.9992, grad_fn=<NegBackward>)
# 第480个epoch的学习率：0.000140
# 第480个epoch的学习率：0.000140
# 490 tensor(56.0852, grad_fn=<AddBackward0>) tensor(-56.0897, grad_fn=<NegBackward>)
# 第490个epoch的学习率：0.000140
# 第490个epoch的学习率：0.000140
# 500 tensor(56.1739, grad_fn=<AddBackward0>) tensor(-56.1972, grad_fn=<NegBackward>)
# 第500个epoch的学习率：0.000098
# 第500个epoch的学习率：0.000098

# %%
# the error of true solution and predicted solution
u_domain=func_u(x_domain)
error_=u_domain-prediction_u
error_1=torch.reshape(error_,(-1,1))
plt.hist(error_1.data.numpy(),bins=10)
# Out:
# (array([  163428.,   719440.,  1943868.,  4714060.,  9478608., 13308772.,
#         12407188., 10031364.,  5500320.,   531176.]),
#  array([-0.30079597, -0.24138422, -0.18197249, -0.12256074, -0.063149  ,
#         -0.00373726,  0.05567449,  0.11508623,  0.17449798,  0.23390971,
#          0.29332146], dtype=float32),
#  <a list of 10 Patch objects>)

# %%
# using x_test to compare the true solution and the predicted solution
prediction_u_ = net_u(x_test_)
prediction_v_ = net_v(x_test_)

plt.plot(u_test_.data.numpy())
plt.plot(prediction_u_.data.numpy())

# %%
# 2d plot of the true solution and the predicted solution
test_u_=torch.reshape(u_test,(mesh_size,mesh_size))
#设置打开画布大小,长8，宽6
plt.figure(figsize=(8,6))
#填充颜色，f即filled
cset=plt.contourf(mesh1.data.numpy(), y_mesh.data.numpy(), test_u_.data.numpy(), 50, cmap="jet")
#画等高线
#plt.contour(x1,x2,test_u_,50)
#设置颜色条
plt.clim(0.00, 0.24)
plt.colorbar(cset)
plt.show()

prediciton_u_=torch.reshape(prediction_u_.data,(mesh_size,mesh_size))
#设置打开画布大小,长8，宽6
plt.figure(figsize=(8,6))
#填充颜色，f即filled
cset=plt.contourf(mesh1.data.numpy(), y_mesh.data.numpy(), prediciton_u_.data.numpy(), 50, cmap="jet")
#画等高线
#plt.contour(x1,x2,test_u_,50)
#设置颜色
plt.clim(0.00, 0.24)
plt.colorbar(cset)
plt.show()

# %%
# 2
iteration = 1001
n1 = 10
n2 = 10

prediction_u = net_u(x_domain_)
prediction_v = net_v(x_domain_)

for t in range(iteration):
    
        
    for i in range(n1):
        loss_u = Loss_u(prediction_u, prediction_v)
        optimizer_u.zero_grad()
        loss_u.backward(retain_graph=True)
        optimizer_u.step()
        #scheduler_u.step() #loss_u
        prediction_u = net_u(x_domain_)
        
    
    for j in range(n2):
        loss_v = Loss_v(prediction_u,prediction_v)
        optimizer_v.zero_grad()
        loss_v.backward(retain_graph=True)
        optimizer_v.step()
        #scheduler_v.step() #loss_v
        prediction_v = net_v(x_domain_)
            

    if t%10==0:
        print(t, loss_u, loss_v)
        print('第%d个epoch的学习率：%f'%(t, optimizer_u.param_groups[0]['lr']))
        print('第%d个epoch的学习率：%f'%(t, optimizer_v.param_groups[0]['lr']))
# Out:
# 0 tensor(56.2051, grad_fn=<AddBackward0>) tensor(-56.2079, grad_fn=<NegBackward>)
# 第0个epoch的学习率：0.000098
# 第0个epoch的学习率：0.000098
# 10 tensor(56.2898, grad_fn=<AddBackward0>) tensor(-56.2940, grad_fn=<NegBackward>)
# 第10个epoch的学习率：0.000098
# 第10个epoch的学习率：0.000098
# 20 tensor(56.3726, grad_fn=<AddBackward0>) tensor(-56.3767, grad_fn=<NegBackward>)
# 第20个epoch的学习率：0.000098
# 第20个epoch的学习率：0.000098
# 30 tensor(56.4544, grad_fn=<AddBackward0>) tensor(-56.4585, grad_fn=<NegBackward>)
# 第30个epoch的学习率：0.000098
# 第30个epoch的学习率：0.000098
# 40 tensor(56.5350, grad_fn=<AddBackward0>) tensor(-56.5391, grad_fn=<NegBackward>)
# 第40个epoch的学习率：0.000098
# 第40个epoch的学习率：0.000098
# 50 tensor(56.6150, grad_fn=<AddBackward0>) tensor(-56.6191, grad_fn=<NegBackward>)
# 第50个epoch的学习率：0.000098
# 第50个epoch的学习率：0.000098
# 60 tensor(56.6883, grad_fn=<AddBackward0>) tensor(-56.6790, grad_fn=<NegBackward>)
# 第60个epoch的学习率：0.000098
# 第60个epoch的学习率：0.000098
# 70 tensor(56.7596, grad_fn=<AddBackward0>) tensor(-56.7634, grad_fn=<NegBackward>)
# 第70个epoch的学习率：0.000098
# 第70个epoch的学习率：0.000098
# 80 tensor(56.8353, grad_fn=<AddBackward0>) tensor(-56.8393, grad_fn=<NegBackward>)
# 第80个epoch的学习率：0.000098
# 第80个epoch的学习率：0.000098
# 90 tensor(56.9103, grad_fn=<AddBackward0>) tensor(-56.9143, grad_fn=<NegBackward>)
# 第90个epoch的学习率：0.000098
# 第90个epoch的学习率：0.000098
# 100 tensor(56.9840, grad_fn=<AddBackward0>) tensor(-56.9882, grad_fn=<NegBackward>)
# 第100个epoch的学习率：0.000098
# 第100个epoch的学习率：0.000098
# 110 tensor(57.0567, grad_fn=<AddBackward0>) tensor(-57.0606, grad_fn=<NegBackward>)
# 第110个epoch的学习率：0.000098
# 第110个epoch的学习率：0.000098
# 120 tensor(57.1280, grad_fn=<AddBackward0>) tensor(-57.1317, grad_fn=<NegBackward>)
# 第120个epoch的学习率：0.000098
# 第120个epoch的学习率：0.000098
# 130 tensor(57.1979, grad_fn=<AddBackward0>) tensor(-57.2016, grad_fn=<NegBackward>)
# 第130个epoch的学习率：0.000098
# 第130个epoch的学习率：0.000098
# 140 tensor(57.2663, grad_fn=<AddBackward0>) tensor(-57.2704, grad_fn=<NegBackward>)
# 第140个epoch的学习率：0.000098
# 第140个epoch的学习率：0.000098
# 150 tensor(57.3346, grad_fn=<AddBackward0>) tensor(-57.3384, grad_fn=<NegBackward>)
# 第150个epoch的学习率：0.000098
# 第150个epoch的学习率：0.000098
# 160 tensor(57.4027, grad_fn=<AddBackward0>) tensor(-57.4058, grad_fn=<NegBackward>)
# 第160个epoch的学习率：0.000098
# 第160个epoch的学习率：0.000098
# 170 tensor(57.4689, grad_fn=<AddBackward0>) tensor(-57.4722, grad_fn=<NegBackward>)
# 第170个epoch的学习率：0.000098
# 第170个epoch的学习率：0.000098
# 180 tensor(57.5350, grad_fn=<AddBackward0>) tensor(-57.5385, grad_fn=<NegBackward>)
# 第180个epoch的学习率：0.000098
# 第180个epoch的学习率：0.000098
# 190 tensor(57.5997, grad_fn=<AddBackward0>) tensor(-57.6032, grad_fn=<NegBackward>)
# 第190个epoch的学习率：0.000098
# 第190个epoch的学习率：0.000098
# 200 tensor(57.6633, grad_fn=<AddBackward0>) tensor(-57.6669, grad_fn=<NegBackward>)
# 第200个epoch的学习率：0.000098
# 第200个epoch的学习率：0.000098
# 210 tensor(57.7263, grad_fn=<AddBackward0>) tensor(-57.7300, grad_fn=<NegBackward>)
# 第210个epoch的学习率：0.000098
# 第210个epoch的学习率：0.000098
# 220 tensor(57.7885, grad_fn=<AddBackward0>) tensor(-57.7919, grad_fn=<NegBackward>)
# 第220个epoch的学习率：0.000098
# 第220个epoch的学习率：0.000098
# 230 tensor(57.8495, grad_fn=<AddBackward0>) tensor(-57.8527, grad_fn=<NegBackward>)
# 第230个epoch的学习率：0.000098
# 第230个epoch的学习率：0.000098
# 240 tensor(57.9094, grad_fn=<AddBackward0>) tensor(-57.9128, grad_fn=<NegBackward>)
# 第240个epoch的学习率：0.000098
# 第240个epoch的学习率：0.000098
# 250 tensor(57.9690, grad_fn=<AddBackward0>) tensor(-57.9713, grad_fn=<NegBackward>)
# 第250个epoch的学习率：0.000098
# 第250个epoch的学习率：0.000098
# 260 tensor(58.0275, grad_fn=<AddBackward0>) tensor(-58.0295, grad_fn=<NegBackward>)
# 第260个epoch的学习率：0.000098
# 第260个epoch的学习率：0.000098
# 270 tensor(58.0844, grad_fn=<AddBackward0>) tensor(-58.0880, grad_fn=<NegBackward>)
# 第270个epoch的学习率：0.000098
# 第270个epoch的学习率：0.000098
# 280 tensor(58.1409, grad_fn=<AddBackward0>) tensor(-58.1448, grad_fn=<NegBackward>)
# 第280个epoch的学习率：0.000098
# 第280个epoch的学习率：0.000098
# 290 tensor(58.1971, grad_fn=<AddBackward0>) tensor(-58.2001, grad_fn=<NegBackward>)
# 第290个epoch的学习率：0.000098
# 第290个epoch的学习率：0.000098
# 300 tensor(58.2521, grad_fn=<AddBackward0>) tensor(-58.2556, grad_fn=<NegBackward>)
# 第300个epoch的学习率：0.000098
# 第300个epoch的学习率：0.000098
# 310 tensor(58.3071, grad_fn=<AddBackward0>) tensor(-58.3097, grad_fn=<NegBackward>)
# 第310个epoch的学习率：0.000098
# 第310个epoch的学习率：0.000098
# 320 tensor(58.3603, grad_fn=<AddBackward0>) tensor(-58.3638, grad_fn=<NegBackward>)
# 第320个epoch的学习率：0.000098
# 第320个epoch的学习率：0.000098
# 330 tensor(58.4135, grad_fn=<AddBackward0>) tensor(-58.4163, grad_fn=<NegBackward>)
# 第330个epoch的学习率：0.000098
# 第330个epoch的学习率：0.000098
# 340 tensor(58.4657, grad_fn=<AddBackward0>) tensor(-58.4687, grad_fn=<NegBackward>)
# 第340个epoch的学习率：0.000098
# 第340个epoch的学习率：0.000098
# 350 tensor(58.5174, grad_fn=<AddBackward0>) tensor(-58.5201, grad_fn=<NegBackward>)
# 第350个epoch的学习率：0.000098
# 第350个epoch的学习率：0.000098
# 360 tensor(58.5681, grad_fn=<AddBackward0>) tensor(-58.5712, grad_fn=<NegBackward>)
# 第360个epoch的学习率：0.000098
# 第360个epoch的学习率：0.000098
# 370 tensor(58.6181, grad_fn=<AddBackward0>) tensor(-58.6216, grad_fn=<NegBackward>)
# 第370个epoch的学习率：0.000098
# 第370个epoch的学习率：0.000098
# 380 tensor(58.6685, grad_fn=<AddBackward0>) tensor(-58.6711, grad_fn=<NegBackward>)
# 第380个epoch的学习率：0.000098
# 第380个epoch的学习率：0.000098
# 390 tensor(58.7177, grad_fn=<AddBackward0>) tensor(-58.7202, grad_fn=<NegBackward>)
# 第390个epoch的学习率：0.000098
# 第390个epoch的学习率：0.000098
# 400 tensor(58.7664, grad_fn=<AddBackward0>) tensor(-58.7690, grad_fn=<NegBackward>)
# 第400个epoch的学习率：0.000098
# 第400个epoch的学习率：0.000098
# 410 tensor(58.8147, grad_fn=<AddBackward0>) tensor(-58.8170, grad_fn=<NegBackward>)
# 第410个epoch的学习率：0.000098
# 第410个epoch的学习率：0.000098
# 420 tensor(58.8619, grad_fn=<AddBackward0>) tensor(-58.8649, grad_fn=<NegBackward>)
# 第420个epoch的学习率：0.000098
# 第420个epoch的学习率：0.000098
# 430 tensor(58.9100, grad_fn=<AddBackward0>) tensor(-58.9121, grad_fn=<NegBackward>)
# 第430个epoch的学习率：0.000098
# 第430个epoch的学习率：0.000098
# 440 tensor(58.9567, grad_fn=<AddBackward0>) tensor(-58.9592, grad_fn=<NegBackward>)
# 第440个epoch的学习率：0.000098
# 第440个epoch的学习率：0.000098
# 450 tensor(59.0030, grad_fn=<AddBackward0>) tensor(-59.0055, grad_fn=<NegBackward>)
# 第450个epoch的学习率：0.000098
# 第450个epoch的学习率：0.000098
# 460 tensor(59.0486, grad_fn=<AddBackward0>) tensor(-59.0511, grad_fn=<NegBackward>)
# 第460个epoch的学习率：0.000098
# 第460个epoch的学习率：0.000098
# 470 tensor(59.0938, grad_fn=<AddBackward0>) tensor(-59.0961, grad_fn=<NegBackward>)
# 第470个epoch的学习率：0.000098
# 第470个epoch的学习率：0.000098
# 480 tensor(59.1386, grad_fn=<AddBackward0>) tensor(-59.1406, grad_fn=<NegBackward>)
# 第480个epoch的学习率：0.000098
# 第480个epoch的学习率：0.000098
# 490 tensor(59.1829, grad_fn=<AddBackward0>) tensor(-59.1855, grad_fn=<NegBackward>)
# 第490个epoch的学习率：0.000098
# 第490个epoch的学习率：0.000098
# 500 tensor(59.2267, grad_fn=<AddBackward0>) tensor(-59.2295, grad_fn=<NegBackward>)
# 第500个epoch的学习率：0.000098
# 第500个epoch的学习率：0.000098
# 510 tensor(59.2704, grad_fn=<AddBackward0>) tensor(-59.2723, grad_fn=<NegBackward>)
# 第510个epoch的学习率：0.000098
# 第510个epoch的学习率：0.000098
# 520 tensor(59.3131, grad_fn=<AddBackward0>) tensor(-59.3155, grad_fn=<NegBackward>)
# 第520个epoch的学习率：0.000098
# 第520个epoch的学习率：0.000098
# 530 tensor(59.3553, grad_fn=<AddBackward0>) tensor(-59.3584, grad_fn=<NegBackward>)
# 第530个epoch的学习率：0.000098
# 第530个epoch的学习率：0.000098
# 540 tensor(59.3973, grad_fn=<AddBackward0>) tensor(-59.4001, grad_fn=<NegBackward>)
# 第540个epoch的学习率：0.000098
# 第540个epoch的学习率：0.000098
# 550 tensor(59.4388, grad_fn=<AddBackward0>) tensor(-59.4414, grad_fn=<NegBackward>)
# 第550个epoch的学习率：0.000098
# 第550个epoch的学习率：0.000098
# 560 tensor(59.4805, grad_fn=<AddBackward0>) tensor(-59.4831, grad_fn=<NegBackward>)
# 第560个epoch的学习率：0.000098
# 第560个epoch的学习率：0.000098
# 570 tensor(59.5212, grad_fn=<AddBackward0>) tensor(-59.5237, grad_fn=<NegBackward>)
# 第570个epoch的学习率：0.000098
# 第570个epoch的学习率：0.000098
# 580 tensor(59.5615, grad_fn=<AddBackward0>) tensor(-59.5642, grad_fn=<NegBackward>)
# 第580个epoch的学习率：0.000098
# 第580个epoch的学习率：0.000098
# 590 tensor(59.6020, grad_fn=<AddBackward0>) tensor(-59.6038, grad_fn=<NegBackward>)
# 第590个epoch的学习率：0.000098
# 第590个epoch的学习率：0.000098
# 600 tensor(59.6419, grad_fn=<AddBackward0>) tensor(-59.6439, grad_fn=<NegBackward>)
# 第600个epoch的学习率：0.000098
# 第600个epoch的学习率：0.000098
# 610 tensor(59.6809, grad_fn=<AddBackward0>) tensor(-59.6838, grad_fn=<NegBackward>)
# 第610个epoch的学习率：0.000098
# 第610个epoch的学习率：0.000098
# 620 tensor(59.7203, grad_fn=<AddBackward0>) tensor(-59.7223, grad_fn=<NegBackward>)
# 第620个epoch的学习率：0.000098
# 第620个epoch的学习率：0.000098
# 630 tensor(59.7584, grad_fn=<AddBackward0>) tensor(-59.7605, grad_fn=<NegBackward>)
# 第630个epoch的学习率：0.000098
# 第630个epoch的学习率：0.000098
# 640 tensor(59.7960, grad_fn=<AddBackward0>) tensor(-59.7987, grad_fn=<NegBackward>)
# 第640个epoch的学习率：0.000098
# 第640个epoch的学习率：0.000098
# 650 tensor(59.8338, grad_fn=<AddBackward0>) tensor(-59.8359, grad_fn=<NegBackward>)
# 第650个epoch的学习率：0.000098
# 第650个epoch的学习率：0.000098
# 660 tensor(59.8709, grad_fn=<AddBackward0>) tensor(-59.8730, grad_fn=<NegBackward>)
# 第660个epoch的学习率：0.000098
# 第660个epoch的学习率：0.000098
# 670 tensor(59.9077, grad_fn=<AddBackward0>) tensor(-59.9097, grad_fn=<NegBackward>)
# 第670个epoch的学习率：0.000098
# 第670个epoch的学习率：0.000098
# 680 tensor(59.9435, grad_fn=<AddBackward0>) tensor(-59.9459, grad_fn=<NegBackward>)
# 第680个epoch的学习率：0.000098
# 第680个epoch的学习率：0.000098
# 690 tensor(59.9795, grad_fn=<AddBackward0>) tensor(-59.9820, grad_fn=<NegBackward>)
# 第690个epoch的学习率：0.000098
# 第690个epoch的学习率：0.000098
# 700 tensor(60.0152, grad_fn=<AddBackward0>) tensor(-60.0176, grad_fn=<NegBackward>)
# 第700个epoch的学习率：0.000098
# 第700个epoch的学习率：0.000098
# 710 tensor(60.0505, grad_fn=<AddBackward0>) tensor(-60.0525, grad_fn=<NegBackward>)
# 第710个epoch的学习率：0.000098
# 第710个epoch的学习率：0.000098
# 720 tensor(60.0856, grad_fn=<AddBackward0>) tensor(-60.0871, grad_fn=<NegBackward>)
# 第720个epoch的学习率：0.000098
# 第720个epoch的学习率：0.000098
# 730 tensor(60.1197, grad_fn=<AddBackward0>) tensor(-60.1220, grad_fn=<NegBackward>)
# 第730个epoch的学习率：0.000098
# 第730个epoch的学习率：0.000098
# 740 tensor(60.1541, grad_fn=<AddBackward0>) tensor(-60.1564, grad_fn=<NegBackward>)
# 第740个epoch的学习率：0.000098
# 第740个epoch的学习率：0.000098
# 750 tensor(60.1878, grad_fn=<AddBackward0>) tensor(-60.1902, grad_fn=<NegBackward>)
# 第750个epoch的学习率：0.000098
# 第750个epoch的学习率：0.000098
# 760 tensor(60.2217, grad_fn=<AddBackward0>) tensor(-60.2238, grad_fn=<NegBackward>)
# 第760个epoch的学习率：0.000098
# 第760个epoch的学习率：0.000098
# 770 tensor(60.2549, grad_fn=<AddBackward0>) tensor(-60.2568, grad_fn=<NegBackward>)
# 第770个epoch的学习率：0.000098
# 第770个epoch的学习率：0.000098
# 780 tensor(60.2879, grad_fn=<AddBackward0>) tensor(-60.2894, grad_fn=<NegBackward>)
# 第780个epoch的学习率：0.000098
# 第780个epoch的学习率：0.000098
# 790 tensor(60.3201, grad_fn=<AddBackward0>) tensor(-60.3224, grad_fn=<NegBackward>)
# 第790个epoch的学习率：0.000098
# 第790个epoch的学习率：0.000098
# 800 tensor(60.3528, grad_fn=<AddBackward0>) tensor(-60.3543, grad_fn=<NegBackward>)
# 第800个epoch的学习率：0.000098
# 第800个epoch的学习率：0.000098
# 810 tensor(60.3846, grad_fn=<AddBackward0>) tensor(-60.3862, grad_fn=<NegBackward>)
# 第810个epoch的学习率：0.000098
# 第810个epoch的学习率：0.000098
# 820 tensor(60.4161, grad_fn=<AddBackward0>) tensor(-60.4177, grad_fn=<NegBackward>)
# 第820个epoch的学习率：0.000098
# 第820个epoch的学习率：0.000098
# 830 tensor(60.4480, grad_fn=<AddBackward0>) tensor(-60.4493, grad_fn=<NegBackward>)
# 第830个epoch的学习率：0.000098
# 第830个epoch的学习率：0.000098
# 840 tensor(60.4801, grad_fn=<AddBackward0>) tensor(-60.4814, grad_fn=<NegBackward>)
# 第840个epoch的学习率：0.000098
# 第840个epoch的学习率：0.000098
# 850 tensor(60.5112, grad_fn=<AddBackward0>) tensor(-60.5134, grad_fn=<NegBackward>)
# 第850个epoch的学习率：0.000098
# 第850个epoch的学习率：0.000098
# 860 tensor(60.5431, grad_fn=<AddBackward0>) tensor(-60.5445, grad_fn=<NegBackward>)
# 第860个epoch的学习率：0.000098
# 第860个epoch的学习率：0.000098
# 870 tensor(60.5743, grad_fn=<AddBackward0>) tensor(-60.5760, grad_fn=<NegBackward>)
# 第870个epoch的学习率：0.000098
# 第870个epoch的学习率：0.000098
# 880 tensor(60.6054, grad_fn=<AddBackward0>) tensor(-60.6067, grad_fn=<NegBackward>)
# 第880个epoch的学习率：0.000098
# 第880个epoch的学习率：0.000098
# 890 tensor(60.6355, grad_fn=<AddBackward0>) tensor(-60.6376, grad_fn=<NegBackward>)
# 第890个epoch的学习率：0.000098
# 第890个epoch的学习率：0.000098
# 900 tensor(60.6657, grad_fn=<AddBackward0>) tensor(-60.6672, grad_fn=<NegBackward>)
# 第900个epoch的学习率：0.000098
# 第900个epoch的学习率：0.000098
# 910 tensor(60.6957, grad_fn=<AddBackward0>) tensor(-60.6969, grad_fn=<NegBackward>)
# 第910个epoch的学习率：0.000098
# 第910个epoch的学习率：0.000098
# 920 tensor(60.7256, grad_fn=<AddBackward0>) tensor(-60.7266, grad_fn=<NegBackward>)
# 第920个epoch的学习率：0.000098
# 第920个epoch的学习率：0.000098
# 930 tensor(60.7546, grad_fn=<AddBackward0>) tensor(-60.7562, grad_fn=<NegBackward>)
# 第930个epoch的学习率：0.000098
# 第930个epoch的学习率：0.000098
# 940 tensor(60.7852, grad_fn=<AddBackward0>) tensor(-60.7868, grad_fn=<NegBackward>)
# 第940个epoch的学习率：0.000098
# 第940个epoch的学习率：0.000098
# 950 tensor(60.8159, grad_fn=<AddBackward0>) tensor(-60.8167, grad_fn=<NegBackward>)
# 第950个epoch的学习率：0.000098
# 第950个epoch的学习率：0.000098
# 960 tensor(60.8447, grad_fn=<AddBackward0>) tensor(-60.8464, grad_fn=<NegBackward>)
# 第960个epoch的学习率：0.000098
# 第960个epoch的学习率：0.000098
# 970 tensor(60.8732, grad_fn=<AddBackward0>) tensor(-60.8754, grad_fn=<NegBackward>)
# 第970个epoch的学习率：0.000098
# 第970个epoch的学习率：0.000098
# 980 tensor(60.9018, grad_fn=<AddBackward0>) tensor(-60.9034, grad_fn=<NegBackward>)
# 第980个epoch的学习率：0.000098
# 第980个epoch的学习率：0.000098
# 990 tensor(60.9298, grad_fn=<AddBackward0>) tensor(-60.9318, grad_fn=<NegBackward>)
# 第990个epoch的学习率：0.000098
# 第990个epoch的学习率：0.000098
# 1000 tensor(60.9582, grad_fn=<AddBackward0>) tensor(-60.9595, grad_fn=<NegBackward>)
# 第1000个epoch的学习率：0.000098
# 第1000个epoch的学习率：0.000098

# %%
# 2d plot of the true solution and the predicted solution
test_u_=torch.reshape(u_test,(mesh_size,mesh_size))
#设置打开画布大小,长8，宽6
plt.figure(figsize=(8,6))
#填充颜色，f即filled
cset=plt.contourf(mesh1.data.numpy(), y_mesh.data.numpy(), test_u_.data.numpy(), 50, cmap="jet")
#画等高线
#plt.contour(x1,x2,test_u_,50)
#设置颜色条
plt.clim(0.00, 0.24)
plt.colorbar(cset)
plt.show()

prediciton_u_=torch.reshape(prediction_u_.data,(mesh_size,mesh_size))
#设置打开画布大小,长8，宽6
plt.figure(figsize=(8,6))
#填充颜色，f即filled
cset=plt.contourf(mesh1.data.numpy(), y_mesh.data.numpy(), prediciton_u_.data.numpy(), 50, cmap="jet")
#画等高线
#plt.contour(x1,x2,test_u_,50)
#设置颜色
plt.clim(0.00, 0.24)
plt.colorbar(cset)
plt.show()

# %%
u_test_=u_test.reshape(10000,1)
prediction_u_1=prediction_u_.reshape(10000,1)
lens = u_test.shape[0]
error_l2 = u_test_-prediction_u_1

# %%
error_l2_=torch.reshape(error_l2,(mesh_size,mesh_size))
#设置打开画布大小,长8，宽6
plt.figure(figsize=(8,6))
#填充颜色，f即filled
cset=plt.contourf(mesh1.data.numpy(), y_mesh.data.numpy(), error_l2_.data.numpy(), 50, cmap="jet")
#画等高线
#plt.contour(x1,x2,test_u_,50)
#设置颜色条
plt.clim(0.00, 0.24)
plt.colorbar(cset)
plt.show()
